# %% [markdown]
# # Testing the code for generating the rotated MNIST dataset

# %%
from rotated_mnist import flattened_rotMNIST, tasks_rotMNIST
import utils
from rotated_dSprites import create_rotated_dsprites_task, display_dsprites_samples

# %%
TRIAL_ID = utils.get_random_string(5)
config = {
    'num_tasks': 6,
    'per_task_rotation': 9,
    'trial': TRIAL_ID,
    'exp_dir': './checkpoints/{}'.format(TRIAL_ID),
}

# %% [markdown]
# ## Flattened Rotations/Tasks (all rotations are flattened)

# %%
train_loader, test_loader = flattened_rotMNIST(config['num_tasks'], config['per_task_rotation'], 256)
# Out:
# 100%|██████████| 9.91M/9.91M [00:01<00:00, 5.77MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 334kB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 3.18MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 11.0MB/s]

# %%
utils.plot_distribution(train_loader, what='class', title='Class Distribution of Rotated MNIST')
utils.plot_distribution(train_loader, what='angle', title='Angle Distribution of Rotated MNIST')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 utils.plot_distribution(train_loader, what='class', title='Class Distribution of Rotated MNIST')
#       2 utils.plot_distribution(train_loader, what='angle', title='Angle Distribution of Rotated MNIST')
#
# File c:\Users\Boudj\Downloads\metalearning-symmetries-master\metalearning-symmetries-master\rotated-datasets-main\utils.py:19, in plot_distribution(dataloader, what, title)
#      16 def plot_distribution(dataloader, what='class', title='Class Distribution of Rotated MNIST'):
#      18     if what == 'class':
# ---> 19         elems = [klass for _, klass, _ in dataloader.dataset]
#      20     elif what == 'angle':
#      21         elems = [angle for _, _, angle in dataloader.dataset]
#
# ...

# %% [markdown]
# ## Separate Rotations/Tasks

# %%
train_loaders, test_loaders = tasks_rotMNIST(config['num_tasks'], config['per_task_rotation'], 256)

# %%
for train_loader in train_loaders:
    utils.plot_rotated_mnist_images(train_loader['loader'], train_loader['task'], train_loader['rot'], num_images=5)

# %%
train_loader, test_loader = create_rotated_dsprites_task(config['num_tasks'], config['per_task_rotation'], 256)
# Out:
# Creating DataLoader for Task 0: Rotation degree -9° (dSprite's rotation_bin 39)
# train_size: 14745 test_size: 3687
# Creating DataLoader for Task 1: Rotation degree 0° (dSprite's rotation_bin 0)
# train_size: 14745 test_size: 3687
# Creating DataLoader for Task 2: Rotation degree 9° (dSprite's rotation_bin 1)
# train_size: 14745 test_size: 3687
# Creating DataLoader for Task 3: Rotation degree 18° (dSprite's rotation_bin 2)
# train_size: 14745 test_size: 3687
# Creating DataLoader for Task 4: Rotation degree 27° (dSprite's rotation_bin 3)
# train_size: 14745 test_size: 3687

# %%
first_task_dataset = train_loader[0]['loader'].dataset

# %%
display_dsprites_samples(first_task_dataset, 5)
# Out:
# 0

# %%
train_loader.keys()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 train_loader.keys()
#
# AttributeError: 'list' object has no attribute 'keys'

# %%
for train_loader in train_loaders:
    utils.plot_rotated_mnist_images(train_loader['loader'], train_loader['task'], train_loader['rot'], num_images=5)
